# %%
import chipwhisperer as cw
import matplotlib.pyplot as plt

n = 4

try :
    scope.dis()
    target.dis()
except Exception as e:
    pass

scope = cw.scope()
target = cw.target(scope)

scope.default_setup()

cw.program_target(scope, cw.programmers.STM32FProgrammer, "./err0r-CWNANO.hex")

scope.arm()


scope.adc.samples = 1000
# Out:
# WARNING:ChipWhisperer NAEUSB:Your firmware is outdated - latest is 0.52. Suggested to update firmware, as you may experience errors
# See https://chipwhisperer.readthedocs.io/en/latest/api.html#firmware-update
# Detected known STMF32: STM32F04xxx
# Extended erase (0x44), this can take ten seconds or more
# Attempting to program 13047 bytes at 0x8000000
# STM32F Programming flash...
# STM32F Reading flash...
# Verified flash OK, 13047 bytes

# %%
import time

scope.io.clkout = 7.5E6
def reboot_flush():            
    scope.io.nrst = False
    time.sleep(0.05)
    scope.io.nrst = "high_z"
    time.sleep(0.05)
    #Flush garbage too
    target.flush()

def reset_target(scope): 
    scope.io.nrst = 'low'
    time.sleep(0.05)
    scope.io.nrst = 'high'
    time.sleep(0.05)

def cap_pass_trace(pass_guess):
    ret = ""
    reset_target(scope)
    num_char = target.in_waiting()
    while num_char > 0:
        ret += target.read(num_char, 16)
        time.sleep(0.01)
        num_char = target.in_waiting()

    scope.arm()
#     target.write(pass_guess)
    target.simpleserial_write('h', pass_guess)

    ret = scope.capture()
    if ret:
        print('Timeout happened during acquisition')

    trace = scope.get_last_trace()
    return trace

# %%
msg = bytearray([1,2,3,4,5,6,7,8])
target.simpleserial_write("h", msg)
print(target.simpleserial_read_witherrors('r', 4))
# Out:
# {'valid': True, 'payload': CWbytearray(b'c5 88 ca 3f'), 'full_response': 'rC588CA3F\n', 'rv': 0}

# %%
import chipwhisperer.common.results.glitch as glitch
gc = glitch.GlitchController(groups=["success", "reset", "normal"], parameters=["repeat", "ext_offset"])
gc.display_stats()
# Out:
# IntText(value=0, description='success count:', disabled=True)
# IntText(value=0, description='reset count:', disabled=True)
# IntText(value=0, description='normal count:', disabled=True)
# FloatSlider(value=0.0, continuous_update=False, description='repeat setting:', disabled=True, max=10.0, readou…
# FloatSlider(value=0.0, continuous_update=False, description='ext_offset setting:', disabled=True, max=10.0, re…

# %%
# %matplotlib inline
import matplotlib.pylab as plt
fig = plt.figure()

# %%
from importlib import reload
import chipwhisperer.common.results.glitch as glitch
from tqdm.notebook import trange
import struct

g_step = 1

gc.set_global_step(g_step)
gc.set_range("repeat", 1,1 )
gc.set_range("ext_offset", 1, 500) #32 56
scope.glitch.repeat = 0

reboot_flush()
sample_size = 1
for glitch_setting in gc.glitch_values():
    scope.glitch.repeat = glitch_setting[0]
    scope.glitch.ext_offset = glitch_setting[1]
    successes = 0
    resets = 0
    for i in range(1):
        target.flush()
            
        scope.arm()
        
        #Do glitch loop
        target.simpleserial_write("h", msg)
        
        ret = scope.capture()
        
        val = target.simpleserial_read_witherrors('r', 4, glitch_timeout=10)#For loop check
        
        if ret:
            print('Timeout - no trigger')
            gc.add("reset", (scope.glitch.repeat, scope.glitch.ext_offset))
            plt.plot(scope.glitch.ext_offset, scope.glitch.repeat, 'xr', alpha=1)
            fig.canvas.draw()
            resets += 1

            #Device is slow to boot?
            reboot_flush()

        else:
            if val['valid'] is False:
                reboot_flush()
                gc.add("reset", (scope.glitch.repeat, scope.glitch.ext_offset))
                plt.plot(scope.glitch.ext_offset, scope.glitch.repeat, 'xr', alpha=1)
                fig.canvas.draw()
                resets += 1
            else:
                print(f'offset:{scope.glitch.ext_offset}, repeat: {scope.glitch.repeat}, o/p: ',[int(i) for i in val['payload']])
                gcnt = struct.unpack("<I", val['payload'])[0]
                
    if successes > 0:                
        print("successes = {}, resets = {}, repeat = {}, ext_offset = {}".format(successes, resets, scope.glitch.repeat, scope.glitch.ext_offset))
print("Done glitching")
# Out:
# offset:1, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:3, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:4, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:6, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:7, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:12, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:15, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:16, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:17, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:18, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:19, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:20, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:21, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:22, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:23, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:30, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:32, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:33, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:34, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:35, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:36, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:37, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:38, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:40, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:41, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:45, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:48, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:49, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:50, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:51, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:52, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:53, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:54, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:55, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:56, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:58, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:60, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:63, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:64, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:65, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:66, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:67, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:68, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:70, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:71, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:73, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:78, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:80, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:81, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:82, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:83, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:84, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:85, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:86, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:88, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:89, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:93, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:96, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:97, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:98, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:99, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:100, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:101, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:102, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:103, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:104, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:106, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:108, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:111, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:112, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:113, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:114, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:115, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:116, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:117, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:118, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:119, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:121, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:126, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:128, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:129, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:130, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:131, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:132, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:133, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:134, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:136, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:137, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:141, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:144, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:145, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:146, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:147, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:148, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:149, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:150, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:151, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:152, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:156, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:159, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:160, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:161, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:162, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:163, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:164, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:165, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:166, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:167, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:174, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:176, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:177, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:178, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:179, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:180, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:181, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:182, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:184, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:185, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:189, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:192, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:193, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:194, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:195, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:196, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:197, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:198, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:199, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:200, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:204, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:207, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:208, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:209, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:210, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:211, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:212, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:213, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:214, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:215, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:217, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:222, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:224, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:225, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:226, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:227, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:228, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:229, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:230, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:232, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:233, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:237, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:240, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:241, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:242, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:243, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:244, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:245, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:247, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:248, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:250, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:252, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:255, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:256, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:257, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:258, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:259, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:260, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:262, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:263, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:270, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:272, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:273, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:274, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:275, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:276, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:277, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:278, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:280, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:285, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:288, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:289, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:291, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:292, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:293, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:294, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:295, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:296, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:298, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:300, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:303, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:304, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:305, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:306, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:307, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:308, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:309, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:310, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:311, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:313, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:318, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:320, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:321, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:322, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:323, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:324, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:325, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:326, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:328, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:333, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:336, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:337, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:338, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:339, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:340, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:341, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:342, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:343, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:344, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:346, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:348, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:351, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:352, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:353, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:354, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:355, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:356, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:358, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:359, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:361, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:366, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:368, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:369, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:370, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:371, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:372, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:373, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:374, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:376, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:381, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:384, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:385, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:386, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:387, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:388, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:389, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:390, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:391, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:392, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:396, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:399, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:400, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:401, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:402, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:403, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:404, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:405, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:406, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:407, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:409, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:414, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:416, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:417, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:418, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:419, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:420, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:421, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:422, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:424, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:425, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:429, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:432, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:433, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:434, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:435, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:436, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:437, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:438, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:439, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:440, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:442, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:444, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:447, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:448, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:449, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:450, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:451, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:452, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:453, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:454, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:455, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:457, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:462, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:464, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:465, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:466, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:467, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:468, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:469, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:470, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:472, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:473, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:477, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:480, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:481, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:482, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:483, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:484, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:485, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:486, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:487, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:488, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:490, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:492, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:495, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:496, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:497, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:498, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:499, repeat: 1, o/p:  [197, 136, 202, 63]
# offset:500, repeat: 1, o/p:  [197, 136, 202, 63]
# Done glitching

# %%
target.dis()
scope.dis()
# Out:
# True
